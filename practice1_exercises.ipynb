# %% [markdown]
# <a href="https://colab.research.google.com/github/dks1532/SNU_BigData_AI_Fintech/blob/main/practice1_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice 1 — Exercises
#
# **Computing Bootcamp | SNU Graduate School of Data Science**
#
# TA: Reeahn Kim
#
# ---
#
# Complete the two exercises below. Each exercise has a function template — fill in the body so the tests pass.

# %% [markdown]
# ## Exercise 1 — Sum of Positive Integers
#
# Write a function `P1` that **takes a list of integers as input**, **adds only the positive integers in the list**, and **returns the sum**.
#
# **Constraints**
# - Return `0` if there are no positive integers in the list.
# - Return `0` for an empty list.
#
# **I/O Examples**
# ```python
# print(P1([1, 2, -3]))     # 3
# print(P1([-1, 0]))        # 0
# print(P1([-5, -10, -3]))  # 0
# print(P1([]))             # 0
# ```

# %%
from typing import List

def P1(numbers: List[int]) -> int:
    """
    Returns the sum of positive integers in the given list.

    [Input]  numbers (List[int]): A list of integers.
    [Output] pos_sum (int): The sum of positive integers in the list.
    [Constraints] Return 0 if there are no positive integers in the list.
    """
    # TODO: Your code here
    pos_sum = 0

    return pos_sum

# %%
# Run the tests
print(P1([1, 2, -3]))     # Expected: 3
print(P1([-1, 0]))        # Expected: 0
print(P1([-5, -10, -3]))  # Expected: 0
print(P1([]))             # Expected: 0

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 2 — Find Duplicates
#
# Write a function `P2` that **takes a list of integers as input**, and **returns a set of numbers that appear two or more times**.
#
# **I/O Examples**
# ```python
# >>> P2([1, 2, 3, 1])
# {1}
#
# >>> P2([1, 1, 2, 3, 3, 3])
# {1, 3}
#
# >>> P2([1, 2, 3, 4, 5])
# set()
# ```

# %%
from typing import List, Set

def P2(numbers: List[int]) -> Set[int]:
    """
    Returns a set of integers that appear two or more times in the input list.

    [Input]  numbers (List[int]): A list of integers.
    [Output] duplicates (Set[int]): Set of numbers that appear 2+ times.
    """
    # TODO: Your code here
    duplicates = set()

    return duplicates

# %%
# Run the tests
print(P2([1, 2, 3, 1]))         # Expected: {1}
print(P2([1, 1, 2, 3, 3, 3]))   # Expected: {1, 3}
print(P2([1, 2, 3, 4, 5]))      # Expected: set()
